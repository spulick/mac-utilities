# %%
from PIL import Image

# %%
im = Image.open("right_original.png")

# %%
l = 110
r = 760
t = 1006 * (1 - (760 - 110) /992) / 2
b = 1006 - t

# %%
k = im.crop((l, t, r, b))

# %%
k.save("right.png")
